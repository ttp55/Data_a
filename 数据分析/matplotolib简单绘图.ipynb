# %%
import matplotlib.pyplot as plt
import numpy as np

# %%
a = [1,2,3]
b = [4,5,6]

# %%
plt.plot(a)#x坐标为a的index

# %%
 plt.plot(a,b)

# %%
# %timeit np.arange(10)
# Out:
# 406 ns ± 5.48 ns per loop (mean ± std. dev. of 7 runs, 1000000 loops each)

# %%
plt.plot(a,b,'r--')#更改画图风格和颜色

# %%
c = [10,8,6]
d = [1,4,0]
plt.plot(a,b,'r--',c,d,'g*')

# %%
t = np.arange(0.0, 2.0, 0.1)
s = np.sin(t*np.pi)

# %%
plt.plot(t,s,'r--')
plt.plot(t*2,s,'--')
plt.title('this is a demo')
# Out:
# Text(0.5, 1.0, 'this is a demo')
