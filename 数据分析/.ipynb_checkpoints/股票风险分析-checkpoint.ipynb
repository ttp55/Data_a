# %%
import numpy as np
import pandas as pd
from pandas import Series, DataFrame
import pandas_datareader as pdr
import matplotlib.pyplot as plt
import seaborn as sns
from datetime import datetime

# %%
top_tech_df = pd.read_csv('../数据分析/top55.csv')

# %%
top_tech_df.head()
# Out:
#          Date        AAPL         AMZN          FB         GOOG       MSFT
# 0   2017/11/3  172.500000  1111.599976  178.919998  1032.479980  84.139999
# 1   2017/11/2  168.110001  1094.219971  178.919998  1025.579956  84.050003
# 2   2017/11/1  166.889999  1103.680054  182.660004  1025.500000  83.180000
# 3  2017/10/31  169.039993  1105.280029  180.059998  1016.640015  83.180000
# 4  2017/10/30  166.720001  1110.849976  179.869995  1017.109985  83.889999

# %%
top_tech_dr = top_tech_df.pct_change()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# D:\Anaconda\lib\site-packages\pandas\core\ops\array_ops.py in _na_arithmetic_op(left, right, op, is_cmp)
#     141     try:
# --> 142         result = expressions.evaluate(op, left, right)
#     143     except TypeError:
#
# D:\Anaconda\lib\site-packages\pandas\core\computation\expressions.py in evaluate(op, a, b, use_numexpr)
#     234             # error: "None" not callable
# --> 235             return _evaluate(op, op_str, a, b)  # type: ignore[misc]
#     236     return _evaluate_standard(op, op_str, a, b)
#
# D:\Anaconda\lib\site-packages\pandas\core\computation\expressions.py in _evaluate_numexpr(op, op_str, a, b)
#     119     if result is None:
# --> 120         result = _evaluate_standard(op, op_str, a, b)
#     121
#
# ...

# %%
top_tech_df.plot(x='Date')
# Out:
# <AxesSubplot:xlabel='Date'>

# %%
top_tech_df[['AAPL','FB','MSFT']].plot()
# Out:
# <AxesSubplot:xlabel='Date'>

# %%
top_tech_df.head()
# Out:
#                   Date        AAPL         AMZN          FB         GOOG  \
# Date
# 2017/11/3    2017/11/3  172.500000  1111.599976  178.919998  1032.479980
# 2017/11/2    2017/11/2  168.110001  1094.219971  178.919998  1025.579956
# 2017/11/1    2017/11/1  166.889999  1103.680054  182.660004  1025.500000
# 2017/10/31  2017/10/31  169.039993  1105.280029  180.059998  1016.640015
# 2017/10/30  2017/10/30  166.720001  1110.849976  179.869995  1017.109985
#
#                  MSFT
# Date
# 2017/11/3   84.139999
# 2017/11/2   84.050003
# 2017/11/1   83.180000
# 2017/10/31  83.180000
# 2017/10/30  83.889999

# %%
sns.jointplot('AMZN','GOOG', top_tech_df, kind='scatter')#应该用top_tech_dr的，但上面的不能用
# Out:
# D:\Anaconda\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y, data. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %%
sns.pairplot(top_tech_df)

# %%
top_tech_df['AAPL'].quantile(0.52)#分析风险
# Out:
# 115.32214028

# %%
top_tech_df['MSFT'].quantile(0.52)
# Out:
# 53.33276924
