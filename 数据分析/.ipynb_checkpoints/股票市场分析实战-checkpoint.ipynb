# %%
import numpy as np
import pandas as pd
from pandas import Series, DataFrame
import pandas_datareader as pdr
import matplotlib.pyplot as plt
import seaborn as sns
from datetime import datetime

# %%
alibaba = pd.read_csv('../数据分析/BABA.csv')
amazon = pd.read_csv('../数据分析/AMZN.csv')

# %%
alibaba.head()
# Out:
#          Date       Open       High        Low      Close  Adj Close    Volume
# 0  2015-09-21  65.379997  66.400002  62.959999  63.900002  63.900002  22355100
# 1  2015-09-22  62.939999  63.270000  61.580002  61.900002  61.900002  14897900
# 2  2015-09-23  61.959999  62.299999  59.680000  60.000000  60.000000  22684600
# 3  2015-09-24  59.419998  60.340000  58.209999  59.919998  59.919998  20645700
# 4  2015-09-25  60.630001  60.840000  58.919998  59.240002  59.240002  17009100

# %%
alibaba['Adj Close'].plot()
# Out:
# <AxesSubplot:>

# %%
alibaba['Volume'].plot()
# Out:
# <AxesSubplot:>

# %%
alibaba['Adj Close'].plot()
amazon['Adj Close'].plot()
# Out:
# <AxesSubplot:>

# %%
alibaba['high-low'] = alibaba['High'] - alibaba['Low']

# %%
alibaba['high-low'].plot()
# Out:
# <AxesSubplot:>

# %%
alibaba['daily-return'] = alibaba['Adj Close'].pct_change()

# %%
alibaba['daily-return'].plot(figsize=(10,4), linestyle='--', marker='*')
# Out:
# <AxesSubplot:>

# %%
alibaba['daily-return'].plot(kind='hist')
# Out:
# <AxesSubplot:ylabel='Frequency'>

# %%
sns.displot(alibaba['daily-return'], kde=True, rug=True,bins=100,color='purple')
