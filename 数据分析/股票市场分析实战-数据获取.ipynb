# %%
import pandas_datareader.data as pdr
alibaba = pdr.get_data_yahoo('BABA')
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-16-7fbc0ce4f0de> in <module>
#       1 import pandas_datareader.data as pdr
# ----> 2 alibaba = pdr.get_data_yahoo('BABA')
#
# D:\Anaconda\lib\site-packages\pandas_datareader\data.py in get_data_yahoo(*args, **kwargs)
#      78
#      79 def get_data_yahoo(*args, **kwargs):
# ---> 80     return YahooDailyReader(*args, **kwargs).read()
#      81
#      82
#
# D:\Anaconda\lib\site-packages\pandas_datareader\base.py in read(self)
#     251         # If a single symbol, (e.g., 'GOOG')
#     252         if isinstance(self.symbols, (string_types, int)):
# --> 253             df = self._read_one_data(self.url, params=self._get_params(self.symbols))
#     254         # Or multiple symbols, (e.g., ['GOOG', 'AAPL', 'MSFT'])
#     255         elif isinstance(self.symbols, DataFrame):
#
# ...

# %%
pdr.DataReader('600797.SS', 'yahoo', '2020-06-06', '2021-11-11')
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-17-5be436a5ba58> in <module>
# ----> 1 pdr.DataReader('600797.SS', 'yahoo', '2020-06-06', '2021-11-11')
#
# D:\Anaconda\lib\site-packages\pandas\util\_decorators.py in wrapper(*args, **kwargs)
#     197                 else:
#     198                     kwargs[new_arg_name] = new_arg_value
# --> 199             return func(*args, **kwargs)
#     200
#     201         return cast(F, wrapper)
#
# D:\Anaconda\lib\site-packages\pandas_datareader\data.py in DataReader(name, data_source, start, end, retry_count, pause, session, api_key)
#     368
#     369     if data_source == "yahoo":
# --> 370         return YahooDailyReader(
#     371             symbols=name,
#     372             start=start,
#
# D:\Anaconda\lib\site-packages\pandas_datareader\base.py in read(self)
# ...
